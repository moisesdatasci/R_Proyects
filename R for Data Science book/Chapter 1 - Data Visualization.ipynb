# %%
install.packages("palmerpenguins")
library(tidyverse)
library(ggplot2)
library(palmerpenguins)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.1     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.3     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘palmerpenguins’
#
#
# The following objects are masked from ‘package:datasets’:
#
#     penguins, penguins_raw

# %%
penguins
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    Torgersen 39.1           18.7          181
# 2   Adelie    Torgersen 39.5           17.4          186
# 3   Adelie    Torgersen 40.3           18.0          195
# 4   Adelie    Torgersen   NA             NA           NA
# 5   Adelie    Torgersen 36.7           19.3          193
# 6   Adelie    Torgersen 39.3           20.6          190
# 7   Adelie    Torgersen 38.9           17.8          181
# 8   Adelie    Torgersen 39.2           19.6          195
# 9   Adelie    Torgersen 34.1           18.1          193
# 10  Adelie    Torgersen 42.0           20.2          190
# 11  Adelie    Torgersen 37.8           17.1          186
# 12  Adelie    Torgersen 37.8           17.3          180
# 13  Adelie    Torgersen 41.1           17.6          182
# 14  Adelie    Torgersen 38.6           21.2          191
# 15  Adelie    Torgersen 34.6           21.1          198
# ...

# %%
glimpse(penguins)
# Out:
# Rows: 344
# Columns: 8
# $ species           <fct> Adelie, Adelie, Adelie, Adelie, Adelie, Adelie, Adel…
# $ island            <fct> Torgersen, Torgersen, Torgersen, Torgersen, Torgerse…
# $ bill_length_mm    <dbl> 39.1, 39.5, 40.3, NA, 36.7, 39.3, 38.9, 39.2, 34.1, …
# $ bill_depth_mm     <dbl> 18.7, 17.4, 18.0, NA, 19.3, 20.6, 17.8, 19.6, 18.1, …
# $ flipper_length_mm <int> 181, 186, 195, NA, 193, 190, 181, 195, 193, 190, 186…
# $ body_mass_g       <int> 3750, 3800, 3250, NA, 3450, 3650, 3625, 4675, 3475, …
# $ sex               <fct> male, female, female, NA, female, male, female, male…
# $ year              <int> 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007…

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g, color = species)
  ) +
    geom_point() +
    geom_smooth(method = 'lm')
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
geom_point(mapping = aes(color = species, shape = species)) +
geom_smooth(method = 'lm')
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
install.packages("ggthemes")
library(ggthemes)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
geom_point(mapping = aes(color = species, shape = species)) +
geom_smooth(method = 'lm') +
labs(
  title = 'Body mass and flipper length',
  subtitle = 'Dimensions dor Adelie, Chinstrap, and Gentoo Penguins',
  x = 'Flipper length (mm)', y = 'Body mass (g)',
  color = 'Species', shape = 'Species'
) +
scale_color_colorblind()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# ## Ejercicios I

# %%
#1. ¿Cuántas filas hay en penguins? ¿Cuántas columnas?
dim(penguins)
# Out:
# [1] 344   8

# %%
#2. ¿Qué describe la variable bill_depth_mm del marco de datos penguins?
?penguins
# bill_depth_mm: a number denoting bill depth (millimeters)

# %%
#3. Haz un gráfico de dispersión de bill_depth_mm frente a bill_length_mm.
ggplot(
  data = penguins,
  mapping = aes(x = bill_length_mm, y = bill_depth_mm)
) +
geom_point(mapping = aes(color = species, shape = species)) +
geom_smooth(method = 'lm')
#Tiene una pendiente negativa, eso significa que mientras mas largo es el lenght, más pequeño es el depth del pico del pinguino
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
#4 ¿Qué ocurre si haces un gráfico de dispersion de especies frente a bill_depth_mm? ¿Cuál sería la mejor elección de geom?
ggplot(
  data = penguins,
  mapping = aes(x = bill_length_mm, y = bill_depth_mm, color = species, shape = species)
) +
geom_point() +
geom_smooth(method = 'lm')
# La mejor opción es hacerlo de manera individual.
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
#5 ¿Por qué da error lo siguiente y como lo solucionarias?
ggplot(
  data = penguins,
  mapping = aes(x = bill_length_mm, y = bill_depth_mm)
  ) +
geom_point()

#Faltaba ingresar las variables para que el gráfico funcionara
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
#6 ¿Qué hace el aegumento na.rm en geom_point()? ¿Cuál es el valor por defecto del argumento? Crea un gráfico de dispersión en el que utilices correctamente este argumento establecido en TRUE
ggplot(
  data = penguins,
  mapping = aes(x = bill_length_mm, y = bill_depth_mm)
  ) +
geom_point(na.rm = TRUE)
# Elimina silenciosaente los valores faltantes en el gráfico. Este argumento está por defecto en FALSE.
# Out:
# plot without title

# %%
#7 Añade la siguiente leyenda al gráfico que hiciste en el ejercicio anterior: 'Los datos procedesn del paquete palmerpenguins'
ggplot(
  data = penguins,
  mapping = aes(x = bill_length_mm, y = bill_depth_mm)
  ) +
geom_point(na.rm = TRUE) +
labs(
  subtitle = 'Los datos proceden del paquete palmerpenguis'
)
# Out:
# plot without title

# %%
#8 Vuelve a crear la siguiente visualización. ¿A qué estética debe asignarse bil_depth_mm? ¿Debe mapearse a nivel global o a nivel geom?
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
geom_point(mapping = aes(color = bill_depth_mm), na.rm = TRUE) +
geom_smooth(method = 'gam', na.rm = TRUE)
# bill_depth_mm debe asignarse de manera global a la estética de color
# Out:
# `geom_smooth()` using formula = 'y ~ s(x, bs = "cs")'
# plot without title

# %%
#9
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g, color = island)
) +
  geom_point() +
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
#10 ¿Tendrán estos dos gráficos un aspecto diferente? ¿Por qué?
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
  geom_point()+
  geom_smooth()

ggplot() +
  geom_point(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = body_mass_g)
  ) +
  geom_smooth(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = body_mass_g)
  )
  # Son gráficos completamente iguales.
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title
# plot without title

# %% [markdown]
# ## Llamadas ggplot2

# %%
ggplot(penguins, aes(x = flipper_length_mm, y = body_mass_g)) +
geom_point(na.rm = TRUE)
# Out:
# plot without title

# %%
#Tubería |>
penguins|>
ggplot(aes(x = flipper_length_mm, y = body_mass_g))+
geom_point(na.rm = TRUE)
# Out:
# plot without title

# %% [markdown]
# # Visualizar Distribuciones

# %% [markdown]
# ## Una variable categórica

# %%
ggplot(penguins, aes(x = species)) +
  geom_bar()
# Out:
# plot without title

# %%
#Para ordenar, se transforma la variable en un factor fct_infreq()
ggplot(penguins, aes(x = fct_infreq(species)))+
  geom_bar()
# Out:
# plot without title

# %% [markdown]
# ## Una variable numérica (cuantitativa)

# %%
ggplot(penguins, aes(x = body_mass_g))+
  geom_histogram(binwidth = 200, na.rm = TRUE)
# Out:
# plot without title

# %%
ggplot(penguins, aes(x = body_mass_g)) +
  geom_histogram(binwidth = 20, na.rm = TRUE)
ggplot(penguins, aes(x = body_mass_g)) +
  geom_histogram(binwidth = 2000)
# Out:
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_bin()`).”
# plot without title
# plot without title

# %%
ggplot(penguins, aes(x = body_mass_g)) +
  geom_density(na.rm = TRUE)
# Out:
# plot without title

# %% [markdown]
# ## Ejercicios

# %%
#1. Haz un gráfico de barras de species de penguins, en el que asignes species a la estética y. ¿En qué se diferencia este gráfico?
ggplot(penguins, aes(y = species))+
  geom_bar()
# De diferencia en que las barras están en el eje y.
# Out:
# plot without title

# %%
#2. ¿En qué se diferencian los dos gráficos siguientes? ¿Qué estética, color o fill, es más útil para cambiar el color de las barras?
ggplot(penguins, aes(x = species)) +
  geom_bar(color = 'red')

ggplot(penguins, aes(x = species)) +
  geom_bar(fill = 'red')

# color es para el borde de la barra, fill es para la barra entera. En este caso, parece ser que fill es más útil al hacer notorio el color rojo
# Out:
# plot without title
# plot without title

# %%
#3. ¿Qué hace el argumento bins en geom_histogram()? ¿para qué sirve?
ggplot(penguins, aes(x = body_mass_g)) +
  geom_histogram(bins = 10)
# bins divide las barras del histograma en la cantidad indicada
# Out:
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_bin()`).”
# plot without title

# %%
ggplot(diamonds, aes(x = carat)) +
  geom_histogram(binwidth = 0.1)
# El valor 0.1 son los que revela los patrones más interesantes. Es el valor preciso, puesto que no lo satura con mucha información como lo haría el 0.01, pero tampoco oculta información importante como lo haría un valor 1 o superior.
# Out:
# plot without title

# %% [markdown]
# ## Una variable numérica y otra categórica

# %%
ggplot(penguins, aes(x = species, y = body_mass_g)) +
  geom_boxplot(na.rm = TRUE)
# Out:
# plot without title

# %%
ggplot(penguins, aes(x = body_mass_g, color = species)) +
  geom_density(linewidth = 0.75,na.rm = TRUE)
# Out:
# plot without title

# %%
ggplot(penguins, aes(x = body_mass_g, fill = species, color = species))+
  geom_density(alpha = 0.5, na.rm = TRUE)
# Out:
# plot without title

# %% [markdown]
# ## Dos variables categóricas

# %%
ggplot(penguins, aes(x = island, fill = species)) +
  geom_bar()
# Out:
# plot without title

# %%
ggplot(penguins, aes(x = island, fill = species)) +
  geom_bar(position = 'fill')
# Out:
# plot without title

# %% [markdown]
# ## Dos variables númericas

# %%
ggplot(penguins, aes(x = flipper_length_mm, y = body_mass_g)) +
  geom_point()
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# ## Tres o más variables

# %%
ggplot(penguins, aes(x = flipper_length_mm, y = body_mass_g)) +
  geom_point(aes(color = species, shape = island))
# Añadir demasiados mapeados estéticos a un gráfico lo desordena y dificulta la comprensión
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
ggplot(penguins, aes(x = flipper_length_mm, y = body_mass_g)) +
  geom_point(aes(color = species, shape = island)) +
  facet_wrap(~island)
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# ### Ejercicios

# %%
#1. ¿Qué variables de mpg son categóricas? ¿Qué variables son numéricas? ¿Cómo puedes ver esta información cuando ejecutes mpg?
glimpse(mpg)
# categoricas: manufacter, model, trans, drv, fl, class
# numericas: displ, year, cyl, cty, hwy
# Out:
# Rows: 234
# Columns: 11
# $ manufacturer <chr> "audi", "audi", "audi", "audi", "audi", "audi", "audi", "…
# $ model        <chr> "a4", "a4", "a4", "a4", "a4", "a4", "a4", "a4 quattro", "…
# $ displ        <dbl> 1.8, 1.8, 2.0, 2.0, 2.8, 2.8, 3.1, 1.8, 1.8, 2.0, 2.0, 2.…
# $ year         <int> 1999, 1999, 2008, 2008, 1999, 1999, 2008, 1999, 1999, 200…
# $ cyl          <int> 4, 4, 4, 4, 6, 6, 6, 4, 4, 4, 4, 6, 6, 6, 6, 6, 6, 8, 8, …
# $ trans        <chr> "auto(l5)", "manual(m5)", "manual(m6)", "auto(av)", "auto…
# $ drv          <chr> "f", "f", "f", "f", "f", "f", "f", "4", "4", "4", "4", "4…
# $ cty          <int> 18, 21, 20, 21, 16, 18, 18, 18, 16, 20, 19, 15, 17, 17, 1…
# $ hwy          <int> 29, 29, 31, 30, 26, 26, 27, 26, 25, 28, 27, 25, 25, 25, 2…
# $ fl           <chr> "p", "p", "p", "p", "p", "p", "p", "p", "p", "p", "p", "p…
# $ class        <chr> "compact", "compact", "compact", "compact", "compact", "c…

# %%
#2. Haz un gráfico de dispersión de hwy frente a displ utilizando el marco de datos mpg. A continuación, asigna una tercera variable numérica a color, luego a size, luego tanto a color como a size, y luego a shape ¿Cómo se comportane estas estéticas de forma diferente para las variables categóricas rente a las numéricas?
ggplot(mpg, aes(x = hwy, y = displ)) +
  geom_point()
# Out:
# plot without title

# %%
ggplot(mpg, aes(x = hwy, y = displ)) +
  geom_point(aes(color = year))
# Out:
# plot without title

# %%
ggplot(mpg, aes(x = hwy, y = displ)) +
  geom_point(aes(size = year))
# Out:
# plot without title

# %%
ggplot(mpg, aes(x = hwy, y = displ)) +
  geom_point(aes(color = year ,size = cty))
# Out:
# plot without title

# %%
ggplot(mpg, aes(x = hwy, y = displ)) +
  geom_point(aes(color = class ,shape = fl))
# Out:
# plot without title

# %%
#3. En el diagrama de dispersión de hwy frente a displ, ¿qué ocurre si asignas la misma variable a varias estéticas?
ggplot(mpg, aes(x = hwy, y = displ)) +
  geom_point(aes(linewidth = 0.5))
#En este tipo de gráfico el linewidth se ignora
# Out:
# Warning message in geom_point(aes(linewidth = 0.5)):
# “Ignoring unknown aesthetics: linewidth”
# plot without title

# %%
#4. ¿Qué ocurre si asignas la misma variable a varias estéticas?
ggplot(mpg, aes(x = hwy, y = displ)) +
  geom_point(aes(size = hwy, color = hwy))
# El gráfico se va acomodando cuando asigno la misma variable a 2 estéticas, pero con 3 o más el gráfico no funciona.
# Out:
# plot without title

# %%
#5 Haz un diagrama de dispersión de bill_depth_mm frnte a bill_length y colorea los puntos por species. ¿Qué revela la coloración por especies sobre la relación entre estas dos variables? ¿Y el facetado por especies?
ggplot(penguins, aes(x = bill_depth_mm, y = bill_length_mm)) +
  geom_point(aes(color = species))

ggplot(penguins, aes(x = bill_depth_mm, y = bill_length_mm)) +
  geom_point(aes(color = species)) +
  facet_wrap(~species)
# La coloración en el primer gráfico muestra una clara difenciación entre las especies con relación a la anchura y profundidad del pico de los pinguinos. Casi no se interceptan los valores.
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title
# plot without title

# %%
#6. ¿Por qué lo siguiente produce dos leyendas separadas? ¿Cómo lo arreglarías para combinar las dos leyendas?
ggplot(
  data = penguins,
  mapping = aes(
    x = bill_length_mm, y = bill_depth_mm,
    color = species, shape = species
  )
) +
  geom_point()
# Aparecen dos leyendas separadas al integrar labs, puesto que labs hace la diferenciación al etiquetar el color de las especies. Al eliminarla, se unifican las leyendas
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
#7. Crea dos gráficos de barras apiladas siguientes ¿Qué pregunta puedes responder con el primero? ¿Qué pregunta puedes responder con el segundo?
ggplot(penguins, aes(x = island, fill = species)) +
  geom_bar(position = 'fill')
ggplot(penguins, aes(x = species, fill = island)) +
  geom_bar(position = 'fill')
# Que pinguinos comparten las islas Dream y Biscoe. Que Isla habita solo una clase de pinguino. Que tipo de pinguino habita en las 3 islas
# Out:
# plot without title
# plot without title

# %% [markdown]
# ## Guardas tus parcelas

# %%
ggplot(mpg, aes(x = class)) +
  geom_bar()
ggplot(mpg, aes(x = cty, y = hwy)) +
  geom_point()
ggsave('mpg-plot.pdf')
#Se guarda el último gráfico, porque está debajo del último.
# Out:
# plot without title
# Saving 6.67 x 6.67 in image
# plot without title

# %%
# con ?ggsave() puedo saber con que formatos permite guardar
